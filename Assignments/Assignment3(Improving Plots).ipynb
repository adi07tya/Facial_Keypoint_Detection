# %% [markdown]
# <a href="https://colab.research.google.com/github/adi07tya/Facial_Keypoint_Detection/blob/master/Assignments/Assignment3(Improving%20Plots).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.tail(10)
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
df_mov_corr = movies.corr()
# Draw the heatmap 
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_mov_corr, annot = True, ax=ax, square=True)

# %%
# Creating a mask for removing duplicates 
fig1, ax1 = plt.subplots(figsize=(10,10))
mask = np.triu(np.ones_like(df_mov_corr, dtype=np.bool))
sns.heatmap(df_mov_corr, mask=mask, ax=ax1, annot = True, square=True)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
train.select_dtypes(include=np.number).hist(figsize=(20,20))
# Find out the redundant features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23774860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f2375bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f237182b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f236c8518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23679748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0f236aaac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f2365fe48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f2361d1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f2361d240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23580908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23531c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f25a95eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f25b91dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23bfd8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23d1db00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23913a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f234e3748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f234969b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23448c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f233fde80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0f233be128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23374390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f233a55f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23359860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f2330eac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0f232c2d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23278f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f23236240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f2326c4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0f2321e710>]],
#       dtype=object)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
 sns.regplot(x="imdb_rating", y="audience_score", data=movies)

# %%
# Change marker of the scatter plot
sns.regplot(x="imdb_rating", y="audience_score", data=movies, scatter_kws={'alpha':0.3, 'color': 'red', 's':200})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
sns.scatterplot(x="petal_length", y="petal_width", data=df, hue="species")
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
df = sns.load_dataset('iris')
plt.subplot(2,2,1)
sns.kdeplot(df['sepal_width'], c='g')
plt.subplot(2,2,2)
sns.kdeplot(df['sepal_length'], c='r')
plt.subplot(2,2,3)
sns.kdeplot(df['petal_width'], c='black')
plt.subplot(2,2,4)
sns.kdeplot(df['petal_length'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:335: MatplotlibDeprecationWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   ax.plot(x, y, color=color, label=label, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:335: MatplotlibDeprecationWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   ax.plot(x, y, color=color, label=label, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:335: MatplotlibDeprecationWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   ax.plot(x, y, color=color, label=label, **kwargs)

# %%
plt.subplot(2,2,1)
sns.kdeplot(df['sepal_width'], cumulative=True)
plt.subplot(2,2,2)
sns.kdeplot(df['sepal_length'], cumulative=True)
plt.subplot(2,2,3)
sns.kdeplot(df['petal_width'], cumulative=True)
plt.subplot(2,2,4)
sns.kdeplot(df['petal_length'], cumulative=True)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
sns.violinplot(x="species", y="sepal_length", data=df)

# %%
# Change the color of each group 
sns.violinplot(x="species", y="sepal_length", data=df, palette=['b','g','m'])
